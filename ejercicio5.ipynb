# %% [markdown]
# **Ejercicio 5**
#
# Escribir una función que reciba una serie de Pandas con el número de ventas de un producto por años y una cadena con el tipo de gráfico a generar (lineas, barras, sectores, areas) y devuelva un diagrama del tipo indicado con la evolución de las ventas por años y con el título “Evolución del número de ventas”.
#
# **Solución**

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
def crear_diagrama(serie_datos, tipo_grafico: str):
    fig, axes = plt.subplots()
    serie_datos.plot(kind=tipo_grafico)
    plt.title('Evolución del número de ventas')
    plt.grid(True)
    plt.show()

# %%
datos = {
    2000:1200,
    2001:840,
    2002:1325,
    2003:1280,
    2004:1500
}
serie_ventas = pd.Series(datos)
serie_ventas
# Out:
# 2000    1200
# 2001     840
# 2002    1325
# 2003    1280
# 2004    1500
# dtype: int64

# %%
crear_diagrama(serie_ventas, 'line')

# %%
crear_diagrama(serie_ventas, 'bar')

# %%
crear_diagrama(serie_ventas, 'pie')

# %%
crear_diagrama(serie_ventas, 'area')
